# %%
pip install nsepy
# Out:
# Collecting nsepyNote: you may need to restart the kernel to use updated packages.
#   Downloading nsepy-0.8.tar.gz (33 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\u978275\anaconda3\lib\site-packages (from nsepy) (4.9.3)
# Requirement already satisfied: requests in c:\users\u978275\anaconda3\lib\site-packages (from nsepy) (2.25.1)
# Requirement already satisfied: numpy in c:\users\u978275\anaconda3\lib\site-packages (from nsepy) (1.20.1)
# Requirement already satisfied: pandas in c:\users\u978275\anaconda3\lib\site-packages (from nsepy) (1.2.4)
# Requirement already satisfied: six in c:\users\u978275\anaconda3\lib\site-packages (from nsepy) (1.15.0)
# Requirement already satisfied: click in c:\users\u978275\anaconda3\lib\site-packages (from nsepy) (7.1.2)
# Requirement already satisfied: lxml in c:\users\u978275\anaconda3\lib\site-packages (from nsepy) (4.6.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\u978275\anaconda3\lib\site-packages (from beautifulsoup4->nsepy) (2.2.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\u978275\anaconda3\lib\site-packages (from pandas->nsepy) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\u978275\anaconda3\lib\site-packages (from pandas->nsepy) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\u978275\anaconda3\lib\site-packages (from requests->nsepy) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\u978275\anaconda3\lib\site-packages (from requests->nsepy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\u978275\anaconda3\lib\site-packages (from requests->nsepy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\u978275\anaconda3\lib\site-packages (from requests->nsepy) (1.26.4)
# Building wheels for collected packages: nsepy
#   Building wheel for nsepy (setup.py): started
#   Building wheel for nsepy (setup.py): finished with status 'done'
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36083 sha256=a6813c287ed85554db3bb9ccc42ed8740f11a28b9b65a4d096b23831298198f6
#   Stored in directory: c:\users\u978275\appdata\local\pip\cache\wheels\b9\2c\cb\d74199e422a1dbc20297d10cfff9c54d03e0b5c6694d49ccdd
# Successfully built nsepy
# Installing collected packages: nsepy
# Successfully installed nsepy-0.8

# %%
import nsepy
import datetime
import pandas as pd

# %%
# Stock list extract from Groww

stock_list = ['RELIANCE', 'TCS', 'HDFCBANK', 'INFY', 'ICICIBANK', 'HINDUNILVR', 'SBI', 'BAJFINANCE', \
              'HDFC', 'BHARTIARTL', 'KOTAKBANK', 'ITC', 'WIPRO', 'HCLTECH', 'ASIANPAINT', 'BAJAJFINSV',\
             'LT', 'AXISBANK', 'MARUTI', 'SUNPHARMA', 'ONGC', 'TITAN', 'ULTRACEMCO', 'JSWSTEEL',\
             'ADANIPORTS', 'NESTLEIND', 'TATASTEEL', 'POWERGRID', 'TATAMOTORS', 'NTPC', 'TECHM', 'HINDALCO', \
             'IOC', 'DIVISLAB', 'HDFCLIFE', 'GRASIM', 'COALINDIA', 'SBILIFE', 'BAJAJ-AUTO', 'M&M', \
             'SHREECEM', 'CIPLA', 'BPCL', 'BRITANNIA', 'INDUSINDBK', 'TATACONSUM', 'DRREDDY', 'EICHERMOT', \
             'UPL', 'HEROMOTOCO']
stock_data = pd.DataFrame()

for sym in stock_list:
#     print(sym)
    d = nsepy.get_history(symbol=sym,start=datetime.date(2010,1,1),end=datetime.date(2021,12,31))
    stock_data = pd.concat([stock_data, d])

# %%
stock_data
# Out:
#                 Symbol Series  Prev Close    Open     High      Low    Last  \
# Date
# 2010-01-04    RELIANCE     EQ     1090.55  1091.1  1091.10  1021.85  1077.3
# 2010-01-05    RELIANCE     EQ     1075.50  1149.9  1149.90  1065.40  1068.7
# 2010-01-06    RELIANCE     EQ     1070.70  1079.9  1094.50  1070.65  1087.0
# 2010-01-07    RELIANCE     EQ     1088.00  1088.0  1115.00  1078.00  1101.9
# 2010-01-08    RELIANCE     EQ     1106.05  1108.0  1113.80  1096.00  1103.9
# ...                ...    ...         ...     ...      ...      ...     ...
# 2021-12-27  HEROMOTOCO     EQ     2392.45  2390.0  2410.20  2371.00  2403.0
# 2021-12-28  HEROMOTOCO     EQ     2402.00  2404.0  2425.00  2395.90  2421.0
# 2021-12-29  HEROMOTOCO     EQ     2417.80  2421.0  2442.80  2410.00  2430.0
# 2021-12-30  HEROMOTOCO     EQ     2433.25  2425.0  2437.85  2412.35  2428.0
# 2021-12-31  HEROMOTOCO     EQ     2431.90  2432.0  2483.60  2432.00  2465.0
#
#               Close     VWAP    Volume      Turnover   Trades  \
# Date
# 2010-01-04  1075.50  1044.44  17520006  1.829863e+15      NaN
# 2010-01-05  1070.70  1078.03   4890040  5.271634e+14      NaN
# 2010-01-06  1088.00  1084.64   5415538  5.873928e+14      NaN
# 2010-01-07  1106.05  1103.49   5988404  6.608116e+14      NaN
# 2010-01-08  1103.15  1104.79   3453926  3.815856e+14      NaN
# ...             ...      ...       ...           ...      ...
# 2021-12-27  2402.00  2396.19    223494  5.355337e+13  17833.0
# 2021-12-28  2417.80  2414.01    265463  6.408308e+13  23619.0
# 2021-12-29  2433.25  2424.43    270407  6.555833e+13  15248.0
# 2021-12-30  2431.90  2425.86    366389  8.888094e+13  18902.0
# 2021-12-31  2462.10  2466.24    253608  6.254592e+13  21620.0
#
#            Deliverable Volume  %Deliverble
# Date
# 2010-01-04           14348117       0.8190
# 2010-01-05            2861065       0.5851
# 2010-01-06            2539975       0.4690
# 2010-01-07            2522438       0.4212
# 2010-01-08            1253746       0.3630
# ...                       ...          ...
# 2021-12-27              71590       0.3203
# 2021-12-28             125199       0.4716
# 2021-12-29             140691       0.5203
# 2021-12-30             255696       0.6979
# 2021-12-31              80927       0.3191
#
# [141965 rows x 14 columns]
